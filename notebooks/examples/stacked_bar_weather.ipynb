# %% [markdown]
# <small>*Notebook auto-generated from [``altair/examples/json/stacked_bar_weather.vl.json``](../../altair/examples/json/stacked_bar_weather.vl.json)*</small>
#
# # Altair Example: Stacked Bar Weather
#
# --

# %%
# Uncomment and run these two lines to enable rendering in JupyterLab/nteract
# from altair import enable_mime_rendering
# enable_mime_rendering()

# %% [markdown]
# ## Load Dataset
# The data comes in the form of a Pandas Dataframe:

# %%
from altair import load_dataset
data = load_dataset("seattle-weather")
data.head()
# Out:
#          date  precipitation  temp_max  temp_min  wind  weather
# 0  2012/01/01            0.0      12.8       5.0   4.7  drizzle
# 1  2012/01/02           10.9      10.6       2.8   4.5     rain
# 2  2012/01/03            0.8      11.7       7.2   2.3     rain
# 3  2012/01/04           20.3      12.2       5.6   4.7     rain
# 4  2012/01/05            1.3       8.9       2.8   6.1     rain

# %% [markdown]
# ## Define Altair Specification

# %%
from altair import *  # Import the altair API

chart = Chart(data).mark_bar().encode(
    color=Color('weather:N',
        legend=Legend(
            title='Weather type',
        ),
        scale=Scale(
            domain=['sun', 'fog', 'drizzle', 'rain', 'snow'],
            range=['#e7ba52', '#c7c7c7', '#aec7e8', '#1f77b4', '#9467bd'],
        ),
    ),
    x=X('date:T',
        axis=Axis(
            title='Month of the year',
        ),
        timeUnit='month',
    ),
    y='count(*):Q',
)

chart.max_rows = len(data)  # Altair 1.2.1 has a max_rows of 500 by default

# %% [markdown]
# IPython rich display will invoke Vega-Lite:

# %%
chart
# Out:
# <div class="vega-embed" id="fb89adb9-a347-443c-8323-5d6ba3752ea1"></div>
#
# <style>
# .vega-embed svg, .vega-embed canvas {
#   border: 1px dotted gray;
# }
#
# .vega-embed .vega-actions a {
#   margin-right: 6px;
# }
# </style>

# %% [markdown]
# ## Output Vega-Lite Specification

# %% [markdown]
# Generate JSON dict, leaving data out:

# %%
chart.to_dict(data=False)
# Out:
# {'$schema': 'https://vega.github.io/schema/vega-lite/v1.2.1.json',
#  'encoding': {'color': {'field': 'weather',
#    'legend': {'title': 'Weather type'},
#    'scale': {'domain': ['sun', 'fog', 'drizzle', 'rain', 'snow'],
#     'range': ['#e7ba52', '#c7c7c7', '#aec7e8', '#1f77b4', '#9467bd']},
#    'type': 'nominal'},
#   'x': {'axis': {'title': 'Month of the year'},
#    'field': 'date',
#    'timeUnit': 'month',
#    'type': 'temporal'},
#   'y': {'aggregate': 'count', 'field': '*', 'type': 'quantitative'}},
#  'mark': 'bar'}
