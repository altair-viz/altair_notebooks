# %% [markdown]
# <small>*Notebook auto-generated from [``altair/examples/json/bubble_health_income.vl.json``](../../altair/examples/json/bubble_health_income.vl.json)*</small>
#
# # Altair Example: Bubble Health Income
#
# A bubble plot showing the correlation between health and income for 187 countries in the world (modified from an example in Lisa Charlotte Rost's blog post 'One Chart, Twelve Charting Libraries' --http://lisacharlotterost.github.io/2016/05/17/one-chart-code/).

# %%
# Uncomment and run these two lines to enable rendering in JupyterLab/nteract
# from altair import enable_mime_rendering
# enable_mime_rendering()

# %% [markdown]
# ## Load Dataset
# The data comes in the form of a Pandas Dataframe:

# %%
from altair import load_dataset
data = load_dataset("gapminder-health-income")
data.head()
# Out:
#        country  income  health  population
# 0  Afghanistan    1925   57.63    32526562
# 1      Albania   10620   76.00     2896679
# 2      Algeria   13434   76.50    39666519
# 3      Andorra   46577   84.10       70473
# 4       Angola    7615   61.00    25021974

# %% [markdown]
# ## Define Altair Specification

# %%
from altair import *  # Import the altair API

chart = Chart(data).mark_circle().encode(
    color=Color(
        value='#000',
    ),
    size='population:Q',
    x=X('income:Q',
        scale=Scale(
            type='log',
        ),
    ),
    y=Y('health:Q',
        scale=Scale(
            zero=False,
        ),
    ),
).configure_cell(
    height=300.0,
    width=500.0,
)

chart.max_rows = len(data)  # Altair 1.2.1 has a max_rows of 500 by default

# %% [markdown]
# IPython rich display will invoke Vega-Lite:

# %%
chart
# Out:
# <div class="vega-embed" id="fd4ee2ec-c746-4cdb-9658-01b1dfd3fb7c"></div>
#
# <style>
# .vega-embed svg, .vega-embed canvas {
#   border: 1px dotted gray;
# }
#
# .vega-embed .vega-actions a {
#   margin-right: 6px;
# }
# </style>

# %% [markdown]
# ## Output Vega-Lite Specification

# %% [markdown]
# Generate JSON dict, leaving data out:

# %%
chart.to_dict(data=False)
# Out:
# {'$schema': 'https://vega.github.io/schema/vega-lite/v1.2.1.json',
#  'config': {'cell': {'height': 300.0, 'width': 500.0}},
#  'encoding': {'color': {'value': '#000'},
#   'size': {'field': 'population', 'type': 'quantitative'},
#   'x': {'field': 'income', 'scale': {'type': 'log'}, 'type': 'quantitative'},
#   'y': {'field': 'health', 'scale': {'zero': False}, 'type': 'quantitative'}},
#  'mark': 'circle'}
