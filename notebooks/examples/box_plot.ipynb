# %% [markdown]
# <small>*Notebook auto-generated from [``altair/examples/json/box_plot.vl.json``](../../altair/examples/json/box_plot.vl.json)*</small>
#
# # Altair Example: Box Plot
#
# A box plot showing mean, min, and max in the US population distribution of age groups in 2000.

# %%
# Uncomment and run these two lines to enable rendering in JupyterLab/nteract
# from altair import enable_mime_rendering
# enable_mime_rendering()

# %% [markdown]
# ## Load Dataset
# The data comes in the form of a Pandas Dataframe:

# %%
from altair import load_dataset
data = load_dataset("population")
data.head()
# Out:
#    age   people  sex  year
# 0    0  1483789    1  1850
# 1    0  1450376    2  1850
# 2    5  1411067    1  1850
# 3    5  1359668    2  1850
# 4   10  1260099    1  1850

# %% [markdown]
# ## Define Altair Specification

# %%
from altair import *  # Import the altair API

chart = LayeredChart(data,
    layers=[Chart().mark_rule().encode(
            x='age:O',
            y=Y('min(people):Q',
                axis=Axis(
                    title='population',
                ),
            ),
            y2='max(people):Q',
        ), Chart().mark_tick().encode(
            size=Size(
                value=5.0,
            ),
            x='age:O',
            y='min(people):Q',
        ), Chart().mark_tick().encode(
            size=Size(
                value=5.0,
            ),
            x='age:O',
            y='max(people):Q',
        ), Chart().mark_bar().encode(
            size=Size(
                value=5.0,
            ),
            x='age:O',
            y='q1(people):Q',
            y2='q3(people):Q',
        ), Chart().mark_tick().encode(
            color=Color(
                value='white',
            ),
            size=Size(
                value=5.0,
            ),
            x='age:O',
            y='mean(people):Q',
        )],
)

chart.max_rows = len(data)  # Altair 1.2.1 has a max_rows of 500 by default

# %% [markdown]
# IPython rich display will invoke Vega-Lite:

# %%
chart
# Out:
# <div class="vega-embed" id="eceb7c55-87f4-4fed-b690-976ba41d773a"></div>
#
# <style>
# .vega-embed svg, .vega-embed canvas {
#   border: 1px dotted gray;
# }
#
# .vega-embed .vega-actions a {
#   margin-right: 6px;
# }
# </style>

# %% [markdown]
# ## Output Vega-Lite Specification

# %% [markdown]
# Generate JSON dict, leaving data out:

# %%
chart.to_dict(data=False)
# Out:
# {'$schema': 'https://vega.github.io/schema/vega-lite/v1.2.1.json',
#  'layers': [{'encoding': {'x': {'field': 'age', 'type': 'ordinal'},
#     'y': {'aggregate': 'min',
#      'axis': {'title': 'population'},
#      'field': 'people',
#      'type': 'quantitative'},
#     'y2': {'aggregate': 'max', 'field': 'people', 'type': 'quantitative'}},
#    'mark': 'rule'},
#   {'encoding': {'size': {'value': 5.0},
#     'x': {'field': 'age', 'type': 'ordinal'},
#     'y': {'aggregate': 'min', 'field': 'people', 'type': 'quantitative'}},
#    'mark': 'tick'},
#   {'encoding': {'size': {'value': 5.0},
#     'x': {'field': 'age', 'type': 'ordinal'},
#     'y': {'aggregate': 'max', 'field': 'people', 'type': 'quantitative'}},
#    'mark': 'tick'},
#   {'encoding': {'size': {'value': 5.0},
#     'x': {'field': 'age', 'type': 'ordinal'},
#     'y': {'aggregate': 'q1', 'field': 'people', 'type': 'quantitative'},
#     'y2': {'aggregate': 'q3', 'field': 'people', 'type': 'quantitative'}},
#    'mark': 'bar'},
#   {'encoding': {'color': {'value': 'white'},
#     'size': {'value': 5.0},
#     'x': {'field': 'age', 'type': 'ordinal'},
#     'y': {'aggregate': 'mean', 'field': 'people', 'type': 'quantitative'}},
#    'mark': 'tick'}]}
