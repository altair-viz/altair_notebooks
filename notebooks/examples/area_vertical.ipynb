# %% [markdown]
# <small>*Notebook auto-generated from [``altair/examples/json/area_vertical.vl.json``](../../altair/examples/json/area_vertical.vl.json)*</small>
#
# # Altair Example: Area Vertical
#
# Area chart showing weight of cars over time (vertical).

# %%
# Uncomment and run these two lines to enable rendering in JupyterLab/nteract
# from altair import enable_mime_rendering
# enable_mime_rendering()

# %% [markdown]
# ## Load Dataset
# The data comes in the form of a Pandas Dataframe:

# %%
from altair import load_dataset
data = load_dataset("cars")
data.head()
# Out:
#    Acceleration  Cylinders  Displacement  Horsepower  Miles_per_Gallon  \
# 0          12.0          8         307.0       130.0              18.0
# 1          11.5          8         350.0       165.0              15.0
# 2          11.0          8         318.0       150.0              18.0
# 3          12.0          8         304.0       150.0              16.0
# 4          10.5          8         302.0       140.0              17.0
#
#                         Name Origin  Weight_in_lbs        Year
# 0  chevrolet chevelle malibu    USA           3504  1970-01-01
# 1          buick skylark 320    USA           3693  1970-01-01
# 2         plymouth satellite    USA           3436  1970-01-01
# 3              amc rebel sst    USA           3433  1970-01-01
# 4                ford torino    USA           3449  1970-01-01

# %% [markdown]
# ## Define Altair Specification

# %%
from altair import *  # Import the altair API

chart = Chart(data).mark_area(
    interpolate='monotone',
).encode(
    x='sum(Weight_in_lbs):Q',
    y=Y('Year:T',
        timeUnit='year',
    ),
)

chart.max_rows = len(data)  # Altair 1.2.1 has a max_rows of 500 by default

# %% [markdown]
# IPython rich display will invoke Vega-Lite:

# %%
chart
# Out:
# <div class="vega-embed" id="a02b2b5a-51e6-4028-a217-51aa45741edc"></div>
#
# <style>
# .vega-embed svg, .vega-embed canvas {
#   border: 1px dotted gray;
# }
#
# .vega-embed .vega-actions a {
#   margin-right: 6px;
# }
# </style>

# %% [markdown]
# ## Output Vega-Lite Specification

# %% [markdown]
# Generate JSON dict, leaving data out:

# %%
chart.to_dict(data=False)
# Out:
# {'$schema': 'https://vega.github.io/schema/vega-lite/v1.2.1.json',
#  'config': {'mark': {'interpolate': 'monotone'}},
#  'encoding': {'x': {'aggregate': 'sum',
#    'field': 'Weight_in_lbs',
#    'type': 'quantitative'},
#   'y': {'field': 'Year', 'timeUnit': 'year', 'type': 'temporal'}},
#  'mark': 'area'}
