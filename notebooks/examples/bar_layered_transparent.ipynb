# %% [markdown]
# <small>*Notebook auto-generated from [``altair/examples/json/bar_layered_transparent.vl.json``](../../altair/examples/json/bar_layered_transparent.vl.json)*</small>
#
# # Altair Example: Bar Layered Transparent
#
# A bar chart showing the US population distribution of age groups and gender in 2000.

# %%
# Uncomment and run these two lines to enable rendering in JupyterLab/nteract
# from altair import enable_mime_rendering
# enable_mime_rendering()

# %% [markdown]
# ## Load Dataset
# The data comes in the form of a Pandas Dataframe:

# %%
from altair import load_dataset
data = load_dataset("population")
data.head()
# Out:
#    age   people  sex  year
# 0    0  1483789    1  1850
# 1    0  1450376    2  1850
# 2    5  1411067    1  1850
# 3    5  1359668    2  1850
# 4   10  1260099    1  1850

# %% [markdown]
# ## Define Altair Specification

# %%
from altair import *  # Import the altair API

chart = Chart(data).mark_bar(
    opacity=0.6,
    stacked='none',
).encode(
    color=Color('gender:N',
        scale=Scale(
            range=['#e377c2', '#1f77b4'],
        ),
    ),
    x=X('age:O',
        scale=Scale(
            bandSize=17.0,
        ),
    ),
    y=Y('sum(people):Q',
        axis=Axis(
            title='population',
        ),
    ),
).transform_data(
    calculate=[Formula(
            expr='datum.sex == 2 ? "Female" : "Male"',
            field='gender',
        )],
    filter='datum.year == 2000',
)

chart.max_rows = len(data)  # Altair 1.2.1 has a max_rows of 500 by default

# %% [markdown]
# IPython rich display will invoke Vega-Lite:

# %%
chart
# Out:
# <div class="vega-embed" id="b84da377-499b-4e93-bb2c-7ae857b0ce1b"></div>
#
# <style>
# .vega-embed svg, .vega-embed canvas {
#   border: 1px dotted gray;
# }
#
# .vega-embed .vega-actions a {
#   margin-right: 6px;
# }
# </style>

# %% [markdown]
# ## Output Vega-Lite Specification

# %% [markdown]
# Generate JSON dict, leaving data out:

# %%
chart.to_dict(data=False)
# Out:
# {'$schema': 'https://vega.github.io/schema/vega-lite/v1.2.1.json',
#  'config': {'mark': {'opacity': 0.6, 'stacked': 'none'}},
#  'encoding': {'color': {'field': 'gender',
#    'scale': {'range': ['#e377c2', '#1f77b4']},
#    'type': 'nominal'},
#   'x': {'field': 'age', 'scale': {'bandSize': 17.0}, 'type': 'ordinal'},
#   'y': {'aggregate': 'sum',
#    'axis': {'title': 'population'},
#    'field': 'people',
#    'type': 'quantitative'}},
#  'mark': 'bar',
#  'transform': {'calculate': [{'expr': 'datum.sex == 2 ? "Female" : "Male"',
#     'field': 'gender'}],
#   'filter': 'datum.year == 2000'}}
