# %% [markdown]
# <small>*Notebook auto-generated from [``altair/examples/json/trellis_anscombe.vl.json``](../../altair/examples/json/trellis_anscombe.vl.json)*</small>
#
# # Altair Example: Trellis Anscombe
#
# Anscombe's Quartet

# %%
# Uncomment and run these two lines to enable rendering in JupyterLab/nteract
# from altair import enable_mime_rendering
# enable_mime_rendering()

# %% [markdown]
# ## Load Dataset
# The data comes in the form of a Pandas Dataframe:

# %%
from altair import load_dataset
data = load_dataset("anscombe")
data.head()
# Out:
#   Series   X     Y
# 0      I  10  8.04
# 1      I   8  6.95
# 2      I  13  7.58
# 3      I   9  8.81
# 4      I  11  8.33

# %% [markdown]
# ## Define Altair Specification

# %%
from altair import *  # Import the altair API

chart = Chart(data).mark_circle(
    opacity=1.0,
).encode(
    column='Series:N',
    x=X('X:Q',
        scale=Scale(
            zero=False,
        ),
    ),
    y=Y('Y:Q',
        scale=Scale(
            zero=False,
        ),
    ),
)

chart.max_rows = len(data)  # Altair 1.2.1 has a max_rows of 500 by default

# %% [markdown]
# IPython rich display will invoke Vega-Lite:

# %%
chart
# Out:
# <div class="vega-embed" id="8db847f8-4c31-469d-ab91-2a3f2c958fea"></div>
#
# <style>
# .vega-embed svg, .vega-embed canvas {
#   border: 1px dotted gray;
# }
#
# .vega-embed .vega-actions a {
#   margin-right: 6px;
# }
# </style>

# %% [markdown]
# ## Output Vega-Lite Specification

# %% [markdown]
# Generate JSON dict, leaving data out:

# %%
chart.to_dict(data=False)
# Out:
# {'$schema': 'https://vega.github.io/schema/vega-lite/v1.2.1.json',
#  'config': {'mark': {'opacity': 1.0}},
#  'encoding': {'column': {'field': 'Series', 'type': 'nominal'},
#   'x': {'field': 'X', 'scale': {'zero': False}, 'type': 'quantitative'},
#   'y': {'field': 'Y', 'scale': {'zero': False}, 'type': 'quantitative'}},
#  'mark': 'circle'}
