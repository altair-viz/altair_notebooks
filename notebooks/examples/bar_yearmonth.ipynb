# %% [markdown]
# <small>*Notebook auto-generated from [``altair/examples/json/bar_yearmonth.vl.json``](../../altair/examples/json/bar_yearmonth.vl.json)*</small>
#
# # Altair Example: Bar Yearmonth
#
# Temperature in Seattle as a bar chart with yearmonth time unit.

# %%
# Uncomment and run these two lines to enable rendering in JupyterLab/nteract
# from altair import enable_mime_rendering
# enable_mime_rendering()

# %% [markdown]
# ## Load Dataset
# The data comes in the form of a Pandas Dataframe:

# %%
from altair import load_dataset
data = load_dataset("seattle-temps")
data.head()
# Out:
#                date  temp
# 0  2010/01/01 00:00  39.4
# 1  2010/01/01 01:00  39.2
# 2  2010/01/01 02:00  39.0
# 3  2010/01/01 03:00  38.9
# 4  2010/01/01 04:00  38.8

# %% [markdown]
# ## Define Altair Specification

# %%
from altair import *  # Import the altair API

chart = Chart(data).mark_bar().encode(
    x=X('date:T',
        axis=Axis(
            format='%B of %Y',
        ),
        scale=Scale(
            type='ordinal',
        ),
        timeUnit='yearmonth',
    ),
    y='mean(temp):Q',
)

chart.max_rows = len(data)  # Altair 1.2.1 has a max_rows of 500 by default

# %% [markdown]
# IPython rich display will invoke Vega-Lite:

# %%
chart
# Out:
# <div class="vega-embed" id="0af3feb7-2138-4200-8579-999899969336"></div>
#
# <style>
# .vega-embed svg, .vega-embed canvas {
#   border: 1px dotted gray;
# }
#
# .vega-embed .vega-actions a {
#   margin-right: 6px;
# }
# </style>

# %% [markdown]
# ## Output Vega-Lite Specification

# %% [markdown]
# Generate JSON dict, leaving data out:

# %%
chart.to_dict(data=False)
# Out:
# {'$schema': 'https://vega.github.io/schema/vega-lite/v1.2.1.json',
#  'encoding': {'x': {'axis': {'format': '%B of %Y'},
#    'field': 'date',
#    'scale': {'type': 'ordinal'},
#    'timeUnit': 'yearmonth',
#    'type': 'temporal'},
#   'y': {'aggregate': 'mean', 'field': 'temp', 'type': 'quantitative'}},
#  'mark': 'bar'}
