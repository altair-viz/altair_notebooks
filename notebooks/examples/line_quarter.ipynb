# %% [markdown]
# <small>*Notebook auto-generated from [``altair/examples/json/line_quarter.vl.json``](../../altair/examples/json/line_quarter.vl.json)*</small>
#
# # Altair Example: Line Quarter
#
# Stock price mean per quarter broken down by years.

# %%
# Uncomment and run these two lines to enable rendering in JupyterLab/nteract
# from altair import enable_mime_rendering
# enable_mime_rendering()

# %% [markdown]
# ## Load Dataset
# The data comes in the form of a Pandas Dataframe:

# %%
from altair import load_dataset
data = load_dataset("stocks")
data.head()
# Out:
#   symbol        date  price
# 0   MSFT  Jan 1 2000  39.81
# 1   MSFT  Feb 1 2000  36.35
# 2   MSFT  Mar 1 2000  43.22
# 3   MSFT  Apr 1 2000  28.37
# 4   MSFT  May 1 2000  25.45

# %% [markdown]
# ## Define Altair Specification

# %%
from altair import *  # Import the altair API

chart = Chart(data).mark_point().encode(
    color='symbol:N',
    column=Column('date:T',
        timeUnit='year',
    ),
    x=X('date:T',
        timeUnit='quarter',
    ),
    y='mean(price):Q',
)

chart.max_rows = len(data)  # Altair 1.2.1 has a max_rows of 500 by default

# %% [markdown]
# IPython rich display will invoke Vega-Lite:

# %%
chart
# Out:
# <div class="vega-embed" id="a84ba812-e852-4219-abf6-625e2394d9e0"></div>
#
# <style>
# .vega-embed svg, .vega-embed canvas {
#   border: 1px dotted gray;
# }
#
# .vega-embed .vega-actions a {
#   margin-right: 6px;
# }
# </style>

# %% [markdown]
# ## Output Vega-Lite Specification

# %% [markdown]
# Generate JSON dict, leaving data out:

# %%
chart.to_dict(data=False)
# Out:
# {'$schema': 'https://vega.github.io/schema/vega-lite/v1.2.1.json',
#  'encoding': {'color': {'field': 'symbol', 'type': 'nominal'},
#   'column': {'field': 'date', 'timeUnit': 'year', 'type': 'temporal'},
#   'x': {'field': 'date', 'timeUnit': 'quarter', 'type': 'temporal'},
#   'y': {'aggregate': 'mean', 'field': 'price', 'type': 'quantitative'}},
#  'mark': 'point'}
