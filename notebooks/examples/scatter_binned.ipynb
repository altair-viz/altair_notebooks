# %% [markdown]
# <small>*Notebook auto-generated from [``altair/examples/json/scatter_binned.vl.json``](../../altair/examples/json/scatter_binned.vl.json)*</small>
#
# # Altair Example: Scatter Binned
#
# --

# %%
# Uncomment and run these two lines to enable rendering in JupyterLab/nteract
# from altair import enable_mime_rendering
# enable_mime_rendering()

# %% [markdown]
# ## Load Dataset
# The data comes in the form of a Pandas Dataframe:

# %%
from altair import load_dataset
data = load_dataset("movies")
data.head()
# Out:
#           Creative_Type Director Distributor  IMDB_Rating  IMDB_Votes  \
# 0                  None     None    Gramercy          6.1      1071.0
# 1                  None     None      Strand          6.9       207.0
# 2                  None     None   Lionsgate          6.8       865.0
# 3                  None     None   Fine Line          NaN         NaN
# 4  Contemporary Fiction     None     Trimark          3.4       165.0
#
#   MPAA_Rating Major_Genre  Production_Budget Release_Date  \
# 0           R        None          8000000.0    12-Jun-98
# 1           R       Drama           300000.0     7-Aug-98
# 2        None      Comedy           250000.0    28-Aug-98
# 3        None      Comedy           300000.0    11-Sep-98
# 4           R       Drama          1000000.0     9-Oct-98
#
#    Rotten_Tomatoes_Rating  Running_Time_min               Source  \
# 0                     NaN               NaN                 None
# ...

# %% [markdown]
# ## Define Altair Specification

# %%
from altair import *  # Import the altair API

chart = Chart(data).mark_point().encode(
    size='count(*):Q',
    x=X('IMDB_Rating:Q',
        bin=Bin(
            maxbins=10.0,
        ),
    ),
    y=Y('Rotten_Tomatoes_Rating:Q',
        bin=Bin(
            maxbins=10.0,
        ),
    ),
)

chart.max_rows = len(data)  # Altair 1.2.1 has a max_rows of 500 by default

# %% [markdown]
# IPython rich display will invoke Vega-Lite:

# %%
chart
# Out:
# <div class="vega-embed" id="50b2a3de-3312-4f4f-9cc2-01330c9e3258"></div>
#
# <style>
# .vega-embed svg, .vega-embed canvas {
#   border: 1px dotted gray;
# }
#
# .vega-embed .vega-actions a {
#   margin-right: 6px;
# }
# </style>

# %% [markdown]
# ## Output Vega-Lite Specification

# %% [markdown]
# Generate JSON dict, leaving data out:

# %%
chart.to_dict(data=False)
# Out:
# {'$schema': 'https://vega.github.io/schema/vega-lite/v1.2.1.json',
#  'encoding': {'size': {'aggregate': 'count',
#    'field': '*',
#    'type': 'quantitative'},
#   'x': {'bin': {'maxbins': 10.0},
#    'field': 'IMDB_Rating',
#    'type': 'quantitative'},
#   'y': {'bin': {'maxbins': 10.0},
#    'field': 'Rotten_Tomatoes_Rating',
#    'type': 'quantitative'}},
#  'mark': 'point'}
