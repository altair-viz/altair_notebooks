# %% [markdown]
# <small>*Notebook auto-generated from [``altair/examples/json/bar_grouped.vl.json``](../../altair/examples/json/bar_grouped.vl.json)*</small>
#
# # Altair Example: Bar Grouped
#
# --

# %%
# Uncomment and run these two lines to enable rendering in JupyterLab/nteract
# from altair import enable_mime_rendering
# enable_mime_rendering()

# %% [markdown]
# ## Load Dataset
# The data comes in the form of a Pandas Dataframe:

# %%
from altair import load_dataset
data = load_dataset("population")
data.head()
# Out:
#    age   people  sex  year
# 0    0  1483789    1  1850
# 1    0  1450376    2  1850
# 2    5  1411067    1  1850
# 3    5  1359668    2  1850
# 4   10  1260099    1  1850

# %% [markdown]
# ## Define Altair Specification

# %%
from altair import *  # Import the altair API

chart = Chart(data).mark_bar().encode(
    color=Color('gender:N',
        scale=Scale(
            range=['#EA98D2', '#659CCA'],
        ),
    ),
    column=Column('age:O',
        axis=Axis(
            axisWidth=1.0,
            offset=-8.0,
            orient='bottom',
        ),
        scale=Scale(
            padding=4.0,
        ),
    ),
    x=X('gender:N',
        axis=False,
        scale=Scale(
            bandSize=6.0,
        ),
    ),
    y=Y('sum(people):Q',
        axis=Axis(
            grid=False,
            title='population',
        ),
    ),
).transform_data(
    calculate=[Formula(
            expr='datum.sex == 2 ? "Female" : "Male"',
            field='gender',
        )],
    filter='datum.year == 2000',
).configure_facet_cell(
    strokeWidth=0.0,
)

chart.max_rows = len(data)  # Altair 1.2.1 has a max_rows of 500 by default

# %% [markdown]
# IPython rich display will invoke Vega-Lite:

# %%
chart
# Out:
# <div class="vega-embed" id="2af06db6-4312-48d0-8eba-724006e33538"></div>
#
# <style>
# .vega-embed svg, .vega-embed canvas {
#   border: 1px dotted gray;
# }
#
# .vega-embed .vega-actions a {
#   margin-right: 6px;
# }
# </style>

# %% [markdown]
# ## Output Vega-Lite Specification

# %% [markdown]
# Generate JSON dict, leaving data out:

# %%
chart.to_dict(data=False)
# Out:
# {'$schema': 'https://vega.github.io/schema/vega-lite/v1.2.1.json',
#  'config': {'facet': {'cell': {'strokeWidth': 0.0}}},
#  'encoding': {'color': {'field': 'gender',
#    'scale': {'range': ['#EA98D2', '#659CCA']},
#    'type': 'nominal'},
#   'column': {'axis': {'axisWidth': 1.0, 'offset': -8.0, 'orient': 'bottom'},
#    'field': 'age',
#    'scale': {'padding': 4.0},
#    'type': 'ordinal'},
#   'x': {'axis': False,
#    'field': 'gender',
#    'scale': {'bandSize': 6.0},
#    'type': 'nominal'},
#   'y': {'aggregate': 'sum',
#    'axis': {'grid': False, 'title': 'population'},
#    'field': 'people',
#    'type': 'quantitative'}},
#  'mark': 'bar',
#  'transform': {'calculate': [{'expr': 'datum.sex == 2 ? "Female" : "Male"',
#     'field': 'gender'}],
#   'filter': 'datum.year == 2000'}}
