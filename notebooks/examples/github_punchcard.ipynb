# %% [markdown]
# <small>*Notebook auto-generated from [``altair/examples/json/github_punchcard.vl.json``](../../altair/examples/json/github_punchcard.vl.json)*</small>
#
# # Altair Example: Github Punchcard
#
# --

# %%
# Uncomment and run these two lines to enable rendering in JupyterLab/nteract
# from altair import enable_mime_rendering
# enable_mime_rendering()

# %% [markdown]
# ## Load Dataset
# The data comes in the form of a Pandas Dataframe:

# %%
from altair import load_dataset
data = load_dataset("github")
data.head()
# Out:
#                   time  count
# 0  2015/01/01 01:00:00      2
# 1  2015/01/01 04:00:00      3
# 2  2015/01/01 05:00:00      1
# 3  2015/01/01 08:00:00      1
# 4  2015/01/01 09:00:00      3

# %% [markdown]
# ## Define Altair Specification

# %%
from altair import *  # Import the altair API

chart = Chart(data).mark_circle().encode(
    size='sum(count):Q',
    x=X('time:T',
        timeUnit='hours',
    ),
    y=Y('time:T',
        timeUnit='day',
    ),
)

chart.max_rows = len(data)  # Altair 1.2.1 has a max_rows of 500 by default

# %% [markdown]
# IPython rich display will invoke Vega-Lite:

# %%
chart
# Out:
# <div class="vega-embed" id="a344520a-b8cd-4232-842f-8ef594bd62e3"></div>
#
# <style>
# .vega-embed svg, .vega-embed canvas {
#   border: 1px dotted gray;
# }
#
# .vega-embed .vega-actions a {
#   margin-right: 6px;
# }
# </style>

# %% [markdown]
# ## Output Vega-Lite Specification

# %% [markdown]
# Generate JSON dict, leaving data out:

# %%
chart.to_dict(data=False)
# Out:
# {'$schema': 'https://vega.github.io/schema/vega-lite/v1.2.1.json',
#  'encoding': {'size': {'aggregate': 'sum',
#    'field': 'count',
#    'type': 'quantitative'},
#   'x': {'field': 'time', 'timeUnit': 'hours', 'type': 'temporal'},
#   'y': {'field': 'time', 'timeUnit': 'day', 'type': 'temporal'}},
#  'mark': 'circle'}
